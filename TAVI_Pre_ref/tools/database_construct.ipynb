# %%
###imports
import os
import pandas
import re
import sqlite3
import pandas as pd
import csv
import chardet
import json

# %%
###文件路径
db_path = "E:/SAIRI/TAVI/Code/data/TAVI_data.db"#数据库路径
csv_file = "E:/SAIRI/TAVI/Code/data/output_with_pubmed_data.csv"#csv_路径
pdf_dir = "E:/SAIRI/TAVI/Code/pdf_downloads"#pdf的文件夹路径
layout_root = "E:/SAIRI/TAVI/Code/extract_downloads"#其他文件夹路径
json_folder = "E:/SAIRI/TAVI/Code/extract_features"#featurejson的路径
output_json_path = "E:/SAIRI/TAVI/Code/data/db_output.json"#输出路径

# %%
###核对现在的数据库路径
db_path1 = os.path.abspath(db_path)  
print("数据库文件路径:", db_path1)
# Out:
# 数据库文件路径: E:\SAIRI\TAVI\Code\data\TAVI_data.db

# %%
###建表语句，在数据库管理软件直接跑，或者用python连接后pao
##目前按照来源建表，可根据实际要求更改
##对于混合数据（如数字+符号）采用TEXT类型，之后若实际情况需要aggregate类操作可以考虑更改
##二元内容目前采用0/1
##部分可以用int节省存储的情况采用varchar，防止前导0的情况导致0012变成12之类的

#来自feature extraction json
#1
CREATE TABLE feature_extraction_result (
    doi VARCHAR(255) UNIQUE,
    death TINYINT(1),
    paravalvular_leak TINYINT(1),
    mean_aortic_gradient VARCHAR(255),
    peak_aortic_gradients VARCHAR(255),
    valve_area VARCHAR(255),
    maximum_velocity VARCHAR(255)     

)

#1
CREATE TABLE feature_extraction_procedure(
    doi VARCHAR(255) UNIQUE,
    valve_diameter VARCHAR(255),
    valve_type VARCHAR(255)

)

#1
CREATE TABLE feature_extraction_pre_info(
    doi VARCHAR(255) UNIQUE,
    mean_gradient VARCHAR(255),
    peak_gradients VARCHAR(255),
    valve_area VARCHAR(255),
    maximum_velocity VARCHAR(255),
    ejection_fraction VARCHAR(255)
)

#1
CREATE TABLE feature_extraction_basic_info(
    doi VARCHAR(255) UNIQUE,
    age INT,
    gender TINYINT(1),
    case1 VARCHAR(255),
    previous_history VARCHAR(255)
)

#来自跑出来的csv
#1
CREATE TABLE from_csv(
    doi VARCHAR(255) UNIQUE, 
    article_title VARCHAR(255),
    source_title VARCHAR(255),
    pmid VARCHAR(10),
    year INT,
    abstract TEXT,
    authors VARCHAR(255),
    keywords VARCHAR(255) 

)

#来自layout以及图片信息
#1
CREATE TABLE from_layout(
    doi VARCHAR(255),
    pdf_path VARCHAR(255),
    image_path VARCHAR(255),
    image_caption TEXT
)

##所有的TEXT或许都用VARCHAR(255)也够用
# Out:
#   Cell In[1], line 5
#     CREATE TABLE feature_extraction_result (
#            ^
# SyntaxError: invalid syntax

# %%
#已跑通
###python制表示例
conn = sqlite3.connect(db_path)
cursor = conn.cursor()
cursor.execute('''
CREATE TABLE from_layout(
    doi VARCHAR(255),
    pdf_path VARCHAR(255),
    image_path VARCHAR(255),
    image_caption TEXT
)
    ''')
conn.commit()
conn.close()
print("数据库表已创建。")
# Out:
# 数据库表已创建。

# %%
# #已跑通
# ###python清表示例
# conn = sqlite3.connect(db_path)
# cursor = conn.cursor()
# table_name = "feature_extraction_result"#要删除的表名

# #删除整个表
# #cursor.execute(f"DROP TABLE IF EXISTS {table_name};")
# #print(f"表 {table_name} 已彻底删除")

# #仅清空数据
# cursor.execute(f"DELETE FROM {table_name};")
# print(f"表 {table_name} 数据已清空")
        
# conn.commit()
# conn.close()
# Out:
# 表 feature_extraction_result 数据已清空

# %%
#已跑通
###从csv里读取数据并插入表
def insert_from_csv(csv_file, db_path):
    # 自动检测 CSV 文件编码
    with open(csv_file, "rb") as f:
        result = chardet.detect(f.read())  # 获取文件编码
        file_encoding = result['encoding']

    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    print("开始从csv写入表")
    with open(csv_file, "r", encoding=file_encoding) as f:
        reader = csv.DictReader(f, delimiter=",")  # 你的 CSV 用的是 Tab 分隔符

        for row in reader:
            # 处理 Year，确保是整数
            year = row["Year"].strip()
            year = int(year) if year.isdigit() else None  # 如果无法转换，则设为 None
            
            # 处理 Keywords，转换 "N/A" 为 NULL
            keywords = row["Keywords"].strip()
            keywords = None if keywords.upper() == "N/A" else keywords
            
            # 执行插入
            cursor.execute('''
                INSERT OR IGNORE INTO from_csv(doi, article_title, source_title, pmid, year, abstract, authors, keywords)
                VALUES (?, ?, ?, ?, ?, ?, ?, ?)
            ''', (
                row["DOI"],  
                row["Article Title"],
                row["Source Title"],
                row["Pubmed Id"],
                year,
                row["Abstract"],
                row["Authors"],
                keywords
            ))

    conn.commit()
    conn.close()
    print("csv数据插入完成。")

# %%
#已跑通
###从特征json写入表
def extract_age(value):
    value = value.strip()
    if value.upper() == "N/A":
        return -1
    numbers = re.findall(r'\d+', value)
    return int(numbers[0]) if numbers else -1

def insert_json_to_db(json_folder, db_path):
    
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    print("开始写入特征 JSON 数据")
    # 遍历指定文件夹下所有 JSON 文件
    for file_name in os.listdir(json_folder):
        if file_name.lower().endswith(".json"):
            file_path = os.path.join(json_folder, file_name)
            print(f"处理文件: {file_path}")
            with open(file_path, "r", encoding="utf-8") as f:
                data = json.load(f)
            
            # 如果文件内容是数组格式，则遍历每个记录，否则直接处理单个记录
            records = data if isinstance(data, list) else [data]
            
            for record in records:
                doi = record.get("doi", "").strip()
                if not doi:
                    continue  # 如果 DOI 为空，则跳过该记录
                # 处理 DOI，将下划线转换成斜杠
                doi = doi.replace("_", "/")
                
                # Basic_Info 
                basic_info = record.get("result", {}).get("Basic_Info", {})
                age = extract_age(basic_info.get("Age", "N/A"))
                gender_str = basic_info.get("Gender", "").strip().lower()
                gender = 1 if gender_str == "male" else 0  # Male=1, Female=0
                case1 = basic_info.get("Case", "")
                previous_history = basic_info.get("Previous_History", "")
                cursor.execute('''
                    INSERT OR IGNORE INTO feature_extraction_basic_info (doi, age, gender, case1, previous_history)
                    VALUES (?, ?, ?, ?, ?)
                ''', (doi, age, gender, case1, previous_history))

                # Pre_Info
                pre_info = record.get("result", {}).get("Pre_Info", {})
                mean_gradient = pre_info.get("Mean_Aortic_Gradient", "N/A")
                peak_gradients = pre_info.get("Peak_Aortic_Gradients", "N/A")
                valve_area_pre = pre_info.get("Valve_Area", "N/A")
                maximum_velocity_pre = pre_info.get("Maximum_Velocity", "N/A")
                ejection_fraction = pre_info.get("Ejection_Fraction", "N/A")
                cursor.execute('''
                    INSERT OR IGNORE INTO feature_extraction_pre_info (doi, mean_gradient, peak_gradients, valve_area, maximum_velocity, ejection_fraction)
                    VALUES (?, ?, ?, ?, ?, ?)
                ''', (doi, mean_gradient, peak_gradients, valve_area_pre, maximum_velocity_pre, ejection_fraction))

                # Procedure
                procedure = record.get("result", {}).get("Procedure", {})
                valve_diameter = procedure.get("Valve_Diameter", "N/A")
                valve_type = procedure.get("Valve_Type", "N/A")
                cursor.execute('''
                    INSERT OR IGNORE INTO feature_extraction_procedure (doi, valve_diameter, valve_type)
                    VALUES (?, ?, ?)
                ''', (doi, valve_diameter, valve_type))
                
                # Result
                result_section = record.get("result", {}).get("Result", {})
                death = 1 if result_section.get("Death") else 0
                paravalvular_leak = 1 if result_section.get("Paravalvular_Leak") else 0
                mean_aortic_gradient = result_section.get("Mean_Aortic_Gradient", "N/A")
                peak_aortic_gradients = result_section.get("Peak_Aortic_Gradients", "N/A")
                valve_area_result = result_section.get("Valve_Area", "N/A")
                maximum_velocity_result = result_section.get("Maximum_Velocity", "N/A")
                cursor.execute('''
                    INSERT OR IGNORE INTO feature_extraction_result (doi, death, paravalvular_leak, mean_aortic_gradient, peak_aortic_gradients, valve_area, maximum_velocity)
                    VALUES (?, ?, ?, ?, ?, ?, ?)
                ''', (doi, death, paravalvular_leak, mean_aortic_gradient, peak_aortic_gradients, valve_area_result, maximum_velocity_result))
    
    conn.commit()
    conn.close()
    print("所有特征JSON记录数据已写入数据库。")

# %%
#已跑通
###layout写入表

def clean_caption(caption):
    
    cleaned_caption = re.sub(r'^(?:fig(?:ure)?\.?\s*\d*[\.\s-]*)', '', caption, flags=re.IGNORECASE) #可根据要求更改
    return cleaned_caption.strip()

def insert_layout_data(pdf_folder, layout_root, db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    print("\n=== 开始处理 PDF 文件 ===")
    pdf_files = os.listdir(pdf_folder)
    print(f"在 {pdf_folder} 目录下找到 {len(pdf_files)} 个文件：", pdf_files)

    for pdf_file in pdf_files:
        if not pdf_file.lower().endswith(".pdf"):
            print(f"跳过非 PDF 文件：{pdf_file}")
            continue
        
        pdf_full_path = os.path.join(pdf_folder, pdf_file)
        pdf_name_raw = os.path.splitext(pdf_file)[0]  # 去掉扩展名
        doi_converted = pdf_name_raw.replace("_", "/")  # 生成 DOI

        print(f"\n>>> 处理 PDF 文件: {pdf_file}")
        print(f"    生成 DOI: {doi_converted}")
        print(f"    PDF 完整路径: {pdf_full_path}")

        # 找到 layout 文件夹
        layout_dir = os.path.join(layout_root, pdf_name_raw)
        if not os.path.isdir(layout_dir):
            print(f"未找到 layout 文件夹：{layout_dir}，跳过 {pdf_file}")
            continue

        # images 目录
        images_dir = os.path.join(layout_dir, "images")
        if not os.path.isdir(images_dir):
            print(f"未找到 images 文件夹：{images_dir}，后续 image_path 设为 N/A")
            image_files_dict = {}
        else:
            image_files = [f for f in os.listdir(images_dir) if os.path.isfile(os.path.join(images_dir, f))]
            image_files_dict = {f: os.path.join(images_dir, f) for f in image_files}
            print(f"    在 {images_dir} 中找到 {len(image_files)} 张图片：", image_files)
        
        # 找到 _content_list.json 文件
        content_list_file = None
        for filename in os.listdir(layout_dir):
            if filename.endswith("_content_list.json"):
                content_list_file = os.path.join(layout_dir, filename)
                break

        if not content_list_file:
            print(f"未找到 _content_list.json 文件，跳过 {pdf_file}")
            continue

        print(f"    读取 content_list.json 文件：{content_list_file}")
        with open(content_list_file, "r", encoding="utf-8") as f:
            try:
                content_list_data = json.load(f)
            except Exception as e:
                print(f"    解析 {content_list_file} 出错: {e}，跳过 {pdf_file}")
                continue

        # 遍历 content_list_data，提取 image_path 和 img_caption
        extracted_images = []
        for entry in content_list_data:
            if entry.get("type") == "image":
                img_path = entry.get("img_path", "").strip()
                if img_path.startswith("images/"):
                    img_filename = img_path.replace("images/", "")
                else:
                    img_filename = img_path

                full_image_path = image_files_dict.get(img_filename, "N/A")
                img_caption_list = entry.get("img_caption", [])
                # 合并 caption，并调用 clean_caption 去掉前缀
                img_caption = " ".join(img_caption_list) if img_caption_list else "N/A"
                img_caption = clean_caption(img_caption)
                
                extracted_images.append((full_image_path, img_caption))
                print(f"        发现图片: {img_filename}")
                print(f"        图片路径: {full_image_path}")
                print(f"        原始图片说明: {' '.join(img_caption_list) if img_caption_list else 'N/A'}")
                print(f"        清理后图片说明: {img_caption}")

        # 遍历 extracted_images，将数据写入数据库
        for full_image_path, img_caption in extracted_images:
            cursor.execute('''
                INSERT OR IGNORE INTO from_layout (doi, pdf_path, image_path, image_caption)
                VALUES (?, ?, ?, ?)
            ''', (doi_converted, pdf_full_path, full_image_path, img_caption))

    conn.commit()
    conn.close()
    print("所有 layout 数据已写入数据库")

# %%
###sql合并写成json
def merge_data(db_path, output_json_path):
    conn = sqlite3.connect(db_path)
    conn.row_factory = sqlite3.Row  # 使查询结果以字典形式返回
    cursor = conn.cursor()

    # 以 from_csv 表为主
    cursor.execute("SELECT * FROM from_csv")
    csv_records = cursor.fetchall()

    merged_list = []
    auto_id = 1

    for rec in csv_records:
        rec = dict(rec)  # 转换为普通字典，可以使用 get 方法
        doi = rec["doi"]
        # 尝试从 from_layout 中获取 PDF 路径（假设所有记录中 PDF 路径相同）
        cursor.execute("SELECT pdf_path FROM from_layout WHERE doi = ?", (doi,))
        layout_pdf_rows = cursor.fetchall()
        if layout_pdf_rows:
            pdf_path = layout_pdf_rows[0]["pdf_path"]
        else:
            pdf_path = rec.get("pdf_path", "N/A")

        # 基本信息
        cursor.execute("SELECT * FROM feature_extraction_basic_info WHERE doi = ?", (doi,))
        basic = cursor.fetchone()
        if basic:
            basic = dict(basic)
            basic_info = {
                "Age": basic["age"],
                "Gender": "Male" if basic["gender"] == 1 else "Female",
                "Case": basic["case1"],
                "Previous_History": basic["previous_history"]
            }
        else:
            basic_info = {}

        # 预处理信息
        cursor.execute("SELECT * FROM feature_extraction_pre_info WHERE doi = ?", (doi,))
        pre = cursor.fetchone()
        if pre:
            pre = dict(pre)
            pre_info = {
                "Mean_Gradient": pre["mean_gradient"],
                "Peak_Gradients": pre["peak_gradients"],
                "Valve_Area": pre["valve_area"],
                "Maximum_Velocity": pre["maximum_velocity"],
                "Ejection_Fraction": pre["ejection_fraction"]
            }
        else:
            pre_info = {}

        # 过程信息
        cursor.execute("SELECT * FROM feature_extraction_procedure WHERE doi = ?", (doi,))
        proc = cursor.fetchone()
        if proc:
            proc = dict(proc)
            procedure = {
                "Valve_Diameter": proc["valve_diameter"],
                "Valve_Type": proc["valve_type"]
            }
        else:
            procedure = {}

        # 结果信息
        cursor.execute("SELECT * FROM feature_extraction_result WHERE doi = ?", (doi,))
        res_rec = cursor.fetchone()
        if res_rec:
            res_rec = dict(res_rec)
            result_info = {
                "Death": True if res_rec["death"] == 1 else False,
                "Paravalvular_Leak": True if res_rec["paravalvular_leak"] == 1 else False,
                "Mean_Gradient": res_rec["mean_aortic_gradient"],
                "Peak_Gradients": res_rec["peak_aortic_gradients"],
                "Valve_Area": res_rec["valve_area"],
                "Maximum_Velocity": res_rec["maximum_velocity"]
            }
        else:
            result_info = {}

        # 文件信息：PDF 路径来自 from_layout（如果有），Images 来自 from_layout（可能多条）
        cursor.execute("SELECT * FROM from_layout WHERE doi = ?", (doi,))
        layout_rows = cursor.fetchall()
        images = []
        for row in layout_rows:
            row = dict(row)
            images.append({
                "path": row["image_path"],
                "caption": row["image_caption"]
            })
        files_info = {
            "PDF": pdf_path,
            "Images": images
        }

        merged_record = {
            "id": auto_id,
            "doi": doi,
            "pmid": rec.get("pmid", ""),
            "title": rec.get("article_title", ""),
            "source": rec.get("source_title", ""),
            "Author": rec.get("authors", ""),
            "Abstract": rec.get("abstract", ""),
            "Keywords": rec.get("keywords", ""),
            "year": rec.get("year", ""),
            "Basic_Info": basic_info,
            "Pre_Info": pre_info,
            "Procedure": procedure,
            "Result": result_info,
            "Files": files_info
        }
        merged_list.append(merged_record)
        auto_id += 1

    conn.close()

    with open(output_json_path, "w", encoding="utf-8") as f_out:
        json.dump(merged_list, f_out, indent=4, ensure_ascii=False)

    print(f"Merged JSON data written to {output_json_path}")

# %%
###main函数

if __name__ == "__main__":
    insert_from_csv(csv_file,db_path)
    insert_json_to_db(json_folder,db_path)
    insert_layout_data(pdf_dir, layout_root, db_path)    
    merge_data(db_path, output_json_path)
    print('Done')
# Out:
# 开始从csv写入表
# csv数据插入完成。
# 开始写入特征 JSON 数据
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_0.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_100.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_1000.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_1100.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_1200.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_200.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_300.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_400.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_500.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_600.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_700.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_800.json
# 处理文件: E:/SAIRI/TAVI/Code/extract_features\feature_extraction_900.json
# 所有特征JSON记录数据已写入数据库。
#
# === 开始处理 PDF 文件 ===
# 在 E:/SAIRI/TAVI/Code/pdf_downloads 目录下找到 1300 个文件： ['10.1001_jamacardio.2018.1579.pdf', '10.1001_jamainternmed.2016.9356.pdf', '10.1001_jamaneurol.2018.1178.pdf', '10.1002_ajmg.a.40377.pdf', '10.1002_ccd.22168.pdf', '10.1002_ccd.22199.pdf', '10.1002_ccd.22378.pdf', '10.1002_ccd.22423.pdf', '10.1002_ccd.22532.pdf', '10.1002_ccd.22609.pdf', '10.1002_cc
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1001_jamainternmed.2016.9356.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1001_jamainternmed.2016.9356\images 中找到 1 张图片： ['1cd32a3dcd8a915aafea3bd98303d008dbd99236c833ca76467ba13f66af6aa0.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1001_jamainternmed.2016.9356\796e1794-e34a-49d4-a48c-d7121adce801_content_list.json
#         发现图片: 1cd32a3dcd8a915aafea3bd98303d008dbd99236c833ca76467ba13f66af6aa0.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1001_jamainternmed.2016.9356\images\1cd32a3dcd8a915aafea3bd98303d008dbd99236c833ca76467ba13f66af6aa0.jpg
#         原始图片说明: Figure. Electrocardiographic Results at Admission
#         清理后图片说明: Electrocardiographic Results at Admission
#
# >>> 处理 PDF 文件: 10.1001_jamaneurol.2018.1178.pdf
#     生成 DOI: 10.1001/jamaneurol.2018.1178
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1001_jamaneurol.2018.1178.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1001_jamaneurol.2018.1178\images 中找到 1 张图片： ['d0e7d20915aac4aade0771c94cc70d1aad8dc45b2e6dc7b385caf737e6c2f8fd.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1001_jamaneurol.2018.1178\70f8050e-e660-42b4-a49b-e854db007fdd_content_list.json
#         发现图片: d0e7d20915aac4aade0771c94cc70d1aad8dc45b2e6dc7b385caf737e6c2f8fd.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1001_jamaneurol.2018.1178\images\d0e7d20915aac4aade0771c94cc70d1aad8dc45b2e6dc7b385caf737e6c2f8fd.jpg
#         原始图片说明: Figure.
#         清理后图片说明:
#
# >>> 处理 PDF 文件: 10.1002_ajmg.a.40377.pdf
#     生成 DOI: 10.1002/ajmg.a.40377
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ajmg.a.40377.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ajmg.a.40377\images 中找到 2 张图片： ['25aad5dd44211952122192309bcad2019fd9f500bb54f0bef75d7f438e2d6d92.jpg', 'b71d24e024387ab789e0777652e399a723d2041b0863f4e344e2df4977ee1a0b.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ajmg.a.40377\36425f60-b70c-4b74-b630-784184238e67_content_list.json
#         发现图片: 25aad5dd44211952122192309bcad2019fd9f500bb54f0bef75d7f438e2d6d92.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ajmg.a.40377\images\25aad5dd44211952122192309bcad2019fd9f500bb54f0bef75d7f438e2d6d92.jpg
#         原始图片说明: FIGURe 1 Clinical features. (a-e) Typical facies seen in geleophysic dysplasia type 1 (GD1) including smooth philtrum, thin upper vermilian, long and upturned mouth, no enamel defects, and micrognathia. Features were stable with age, no coarsening. Note the hearing aid in (d). (f,g,h) Extremity findings including brachydactyly, progressive DIP and PIP contractures, and plantar flexion contractures. No evidence of clubbing was found. (i-I) Typical posture and proportions with micromelia, relative acromelia, joint contractures, and thickened skin over knees and ankles. Chest is short and broad. The patient was 3 years in (a,i), 9 years in (h,j), 13 years in (b,f ), 22 years in (c), and 48 years in (d,e,k) [Color figure can be viewed at wileyonlinelibrary.com]
#         清理后图片说明: Clinical features. (a-e) Typical facies seen in geleophysic dysplasia type 1 (GD1) including smooth philtrum, thin upper vermilian, long and upturned mouth, no enamel defects, and micrognathia. Features were stable with age, no coarsening. Note the hearing aid in (d). (f,g,h) Extremity findings including brachydactyly, progressive DIP and PIP contractures, and plantar flexion contractures. No evidence of clubbing was found. (i-I) Typical posture and proportions with micromelia, relative acromelia, joint contractures, and thickened skin over knees and ankles. Chest is short and broad. The patient was 3 years in (a,i), 9 years in (h,j), 13 years in (b,f ), 22 years in (c), and 48 years in (d,e,k) [Color figure can be viewed at wileyonlinelibrary.com]
#         发现图片: b71d24e024387ab789e0777652e399a723d2041b0863f4e344e2df4977ee1a0b.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ajmg.a.40377\images\b71d24e024387ab789e0777652e399a723d2041b0863f4e344e2df4977ee1a0b.jpg
#         原始图片说明: FIGure 2 Multiplanar reformations of computed tomographic images show (a) left ventricular outflow tract with a thickened calcified aortic valve (white arrow) with an annulus dimension of 18  12 mm and a subaortic membrane (yellow arrow); (b) dilated ascending aorta. (Ao) measured 3.2 cm (2.4 cm/m?, Z score + 4.3), dilated brachiocephalic artery (BC), and dilated main pulmonary artery (PA) with a maximum dimension of 4.3 cm (Z score + 6.7); (c) iliofemoral arteries with minimum intraluminal dimension of 6.4 mm; (d) pectus excavatum with the sternum abutting the right ventricular free wall; (e) thoracic scoliosis and dilated descending aorta; and (f ) tracheobronchial tree demonstrating bronchomalacia. The patient was successfully treated by transcatheter aortic valve implantation using a 23 mm CoreValve Evolut-R (Medtronic) via a right transfemoral approach [Color figure can be viewed at wileyonlinelibrary.com]
#         清理后图片说明: Multiplanar reformations of computed tomographic images show (a) left ventricular outflow tract with a thickened calcified aortic valve (white arrow) with an annulus dimension of 18  12 mm and a subaortic membrane (yellow arrow); (b) dilated ascending aorta. (Ao) measured 3.2 cm (2.4 cm/m?, Z score + 4.3), dilated brachiocephalic artery (BC), and dilated main pulmonary artery (PA) with a maximum dimension of 4.3 cm (Z score + 6.7); (c) iliofemoral arteries with minimum intraluminal dimension of 6.4 mm; (d) pectus excavatum with the sternum abutting the right ventricular free wall; (e) thoracic scoliosis and dilated descending aorta; and (f ) tracheobronchial tree demonstrating bronchomalacia. The patient was successfully treated by transcatheter aortic valve implantation using a 23 mm CoreValve Evolut-R (Medtronic) via a right transfemoral approach [Color figure can be viewed at wileyonlinelibrary.com]
#
# >>> 处理 PDF 文件: 10.1002_ccd.22168.pdf
#     生成 DOI: 10.1002/ccd.22168
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22168.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22168\images 中找到 3 张图片： ['3a43e4cfbcc4d1e9841bd9d8130510ae2680c2fd4c1a95a6722bb4c0ce684c0b.jpg', '597acb3fe8559c504babb648610d406c78099a0e0d496c0b96746737be356d6f.jpg', 'c6a38931371a39c62763a11a0b3d2cb345e5e6698d8a1f3dc098bdb8d50ee3c6.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22168\06bd2fb0-db94-4b8b-897c-e73df9e982ef_content_list.json
#         发现图片: 597acb3fe8559c504babb648610d406c78099a0e0d496c0b96746737be356d6f.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22168\images\597acb3fe8559c504babb648610d406c78099a0e0d496c0b96746737be356d6f.jpg
#         原始图片说明: Fig. 1. Transesophageal echocardiograhy images [(A), long axis view; (B), short axis view]. following transcatheter valve implantation showing the presence of severe paravalvular aortic regurgitation (white arrows). [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.]
#         清理后图片说明: Transesophageal echocardiograhy images [(A), long axis view; (B), short axis view]. following transcatheter valve implantation showing the presence of severe paravalvular aortic regurgitation (white arrows). [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.]
#         发现图片: 3a43e4cfbcc4d1e9841bd9d8130510ae2680c2fd4c1a95a6722bb4c0ce684c0b.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22168\images\3a43e4cfbcc4d1e9841bd9d8130510ae2680c2fd4c1a95a6722bb4c0ce684c0b.jpg
#         原始图片说明: Fig. 2. Fluoroscopy and angiographic images showing (A) the positioning of a second Edwards-SAPIEN valve (thick white arrow) within the first one (thin white arrow), (B) implanta-. tion of the second valve, and (C) following implantation of the second valve..
#         清理后图片说明: Fluoroscopy and angiographic images showing (A) the positioning of a second Edwards-SAPIEN valve (thick white arrow) within the first one (thin white arrow), (B) implanta-. tion of the second valve, and (C) following implantation of the second valve..
#         发现图片: c6a38931371a39c62763a11a0b3d2cb345e5e6698d8a1f3dc098bdb8d50ee3c6.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22168\images\c6a38931371a39c62763a11a0b3d2cb345e5e6698d8a1f3dc098bdb8d50ee3c6.jpg
#         原始图片说明: Fig. 3. Transesophageal echocardiography images [(A), long axis view; (B), short axis view]. following valve-in-valve implantation showing trivial paravalvular leak (white arrows). [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.]
#         清理后图片说明: Transesophageal echocardiography images [(A), long axis view; (B), short axis view]. following valve-in-valve implantation showing trivial paravalvular leak (white arrows). [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.]
#
# >>> 处理 PDF 文件: 10.1002_ccd.22199.pdf
#     生成 DOI: 10.1002/ccd.22199
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22199.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22199\images 中找到 6 张图片： ['2d03ed3ace5882fbffc452e521474a942d93274548dd79d9b7d7d898d31f1d96.jpg', '6c02dadaadbc05023f3eff2f81367746638d900111d9ca3eec57c3e814f560c7.jpg', '8526a955abb3a28234158bccb573fc326a92443de9631558b71878f091ec07e2.jpg', '8972c4510b746eba91edabc12261a063fc0649e8dc0bd99883a758896ed2b679.jpg', 'c058c081db3ef4fbb221d10c5d2e2df0f3606b40eb1307bb87dd2a2ed2df7e08.jpg', 'c55163d15a0d80152c49354c2e6edf7889aef911bf147bdd58da108d98af16df.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22199\3e48bac7-2a8e-482a-9b64-d1fea891c066_content_list.json
#         发现图片: 8526a955abb3a28234158bccb573fc326a92443de9631558b71878f091ec07e2.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22199\images\8526a955abb3a28234158bccb573fc326a92443de9631558b71878f091ec07e2.jpg
#         原始图片说明: Fig. 1. Aortography after CoreValve implantation showing periprosthetic leaks.
#         清理后图片说明: Aortography after CoreValve implantation showing periprosthetic leaks.
#         发现图片: 6c02dadaadbc05023f3eff2f81367746638d900111d9ca3eec57c3e814f560c7.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22199\images\6c02dadaadbc05023f3eff2f81367746638d900111d9ca3eec57c3e814f560c7.jpg
#         原始图片说明: Fig. 2. Evidence of two, significant paraprosthetic leaks on postprocedural transthoracic echocardiography. [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.]
#         清理后图片说明: Evidence of two, significant paraprosthetic leaks on postprocedural transthoracic echocardiography. [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.]
#         发现图片: c55163d15a0d80152c49354c2e6edf7889aef911bf147bdd58da108d98af16df.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22199\images\c55163d15a0d80152c49354c2e6edf7889aef911bf147bdd58da108d98af16df.jpg
#         原始图片说明: Fig. 3. Planned positions of the valve-in-valve ex vivo. [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.].
#         清理后图片说明: Planned positions of the valve-in-valve ex vivo. [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.].
#         发现图片: 2d03ed3ace5882fbffc452e521474a942d93274548dd79d9b7d7d898d31f1d96.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22199\images\2d03ed3ace5882fbffc452e521474a942d93274548dd79d9b7d7d898d31f1d96.jpg
#         原始图片说明: Fig. 4. The Sapien valve is positioned at the level of the native aortic annulus (A) and then delivered by balloon inflation into the CoreValve (B)..
#         清理后图片说明: The Sapien valve is positioned at the level of the native aortic annulus (A) and then delivered by balloon inflation into the CoreValve (B)..
#         发现图片: 8972c4510b746eba91edabc12261a063fc0649e8dc0bd99883a758896ed2b679.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22199\images\8972c4510b746eba91edabc12261a063fc0649e8dc0bd99883a758896ed2b679.jpg
#         原始图片说明: Fig. 5. Aortography performed after valve-in-valve procedure. Only a trivial paravalvular leak is observable.
#         清理后图片说明: Aortography performed after valve-in-valve procedure. Only a trivial paravalvular leak is observable.
#         发现图片: c058c081db3ef4fbb221d10c5d2e2df0f3606b40eb1307bb87dd2a2ed2df7e08.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22199\images\c058c081db3ef4fbb221d10c5d2e2df0f3606b40eb1307bb87dd2a2ed2df7e08.jpg
#         原始图片说明: Fig. 6. Pressure waveform before (left) and after (right) valve-in-valve procedure.
#         清理后图片说明: Pressure waveform before (left) and after (right) valve-in-valve procedure.
#
# >>> 处理 PDF 文件: 10.1002_ccd.22378.pdf
#     生成 DOI: 10.1002/ccd.22378
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22378.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22378\images 中找到 3 张图片： ['522cbb871a2efeee1936d318fe7db82d66d6624a9ae8a8876c18133a3499fd40.jpg', '7c0a5f5a10d6ed08a7ff4945840cba3e2a6f18e7366ff32276ac9bc2d40497a7.jpg', 'bc4088bbd4bca958fe1b6fab136b2bad8451c0007f6aa0990540f29e2e7bbe46.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22378\95667338-e250-4921-b504-49b493e24c38_content_list.json
#         发现图片: bc4088bbd4bca958fe1b6fab136b2bad8451c0007f6aa0990540f29e2e7bbe46.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22378\images\bc4088bbd4bca958fe1b6fab136b2bad8451c0007f6aa0990540f29e2e7bbe46.jpg
#         原始图片说明: Fig. 1. (A) CT angiogram of the abdominal aorta and the iliac/ (right/left) of the second patient. The locations most severely femoral arteries of the first patient. Note the excessive wall stenosed are shown with an arrow (left iliac artery minimul. calcification, as well as the high grade bilateral stenosis at. diameter 4.5 mm, right iliac artery minimum diameter 3.4 mm. the aortic bifurcation (arrow). (B) CT of the first patient, show-. Note also the severe diffuse vessel calcification. (D) CT angic. ing severe calcification of the ascending aorta starting 7 cm gram of the second patient, showing the origin of the left sut above the aortic valve level. The left subclavian artery is also clavian artery from the aortic arch (minimum diameter 4. unsuitable for TAVI. (C) CT angiogram of iliac/femoral arteries mm).
#         清理后图片说明: (A) CT angiogram of the abdominal aorta and the iliac/ (right/left) of the second patient. The locations most severely femoral arteries of the first patient. Note the excessive wall stenosed are shown with an arrow (left iliac artery minimul. calcification, as well as the high grade bilateral stenosis at. diameter 4.5 mm, right iliac artery minimum diameter 3.4 mm. the aortic bifurcation (arrow). (B) CT of the first patient, show-. Note also the severe diffuse vessel calcification. (D) CT angic. ing severe calcification of the ascending aorta starting 7 cm gram of the second patient, showing the origin of the left sut above the aortic valve level. The left subclavian artery is also clavian artery from the aortic arch (minimum diameter 4. unsuitable for TAVI. (C) CT angiogram of iliac/femoral arteries mm).
#         发现图片: 7c0a5f5a10d6ed08a7ff4945840cba3e2a6f18e7366ff32276ac9bc2d40497a7.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22378\images\7c0a5f5a10d6ed08a7ff4945840cba3e2a6f18e7366ff32276ac9bc2d40497a7.jpg
#         原始图片说明: Fig. 2. (A) Through a mini-sternotomy, direct access to the ascending aorta was obtained.. (B) The 18 F sheath is being introduced into the ascending aorta, under visual and fluoroscopic guidance. (C) The 18 F sheath is introduced into the ascending aorta. Through it, the. balloon valvuloplasty and CoreValve implantation will take place. (D) Tabaksbeutelnaht. (tobacco pouch suture) technique, for surgical closure of the 18 F access site on the anterior. aortic wall.
#         清理后图片说明: (A) Through a mini-sternotomy, direct access to the ascending aorta was obtained.. (B) The 18 F sheath is being introduced into the ascending aorta, under visual and fluoroscopic guidance. (C) The 18 F sheath is introduced into the ascending aorta. Through it, the. balloon valvuloplasty and CoreValve implantation will take place. (D) Tabaksbeutelnaht. (tobacco pouch suture) technique, for surgical closure of the 18 F access site on the anterior. aortic wall.
#         发现图片: 522cbb871a2efeee1936d318fe7db82d66d6624a9ae8a8876c18133a3499fd40.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22378\images\522cbb871a2efeee1936d318fe7db82d66d6624a9ae8a8876c18133a3499fd40.jpg
#         原始图片说明: Fig. 3.  (A) The 18 F sheath (arrow) is introduced into the ascending aorta. Through it the left. ventricle is accessed. (B) Aortic valve balloon valvuloplasty. (C) The CoreValve prosthesis is. advanced across the aortic valve. Notice the close proximity of the 18 F sheath's tip to the proximal part of the prosthesis. (D) Final result. The CoreValve prosthesis sits in its anatomic. position.
#         清理后图片说明: (A) The 18 F sheath (arrow) is introduced into the ascending aorta. Through it the left. ventricle is accessed. (B) Aortic valve balloon valvuloplasty. (C) The CoreValve prosthesis is. advanced across the aortic valve. Notice the close proximity of the 18 F sheath's tip to the proximal part of the prosthesis. (D) Final result. The CoreValve prosthesis sits in its anatomic. position.
#
# >>> 处理 PDF 文件: 10.1002_ccd.22423.pdf
#     生成 DOI: 10.1002/ccd.22423
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22423.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22423\images 中找到 4 张图片： ['145f64c2b799800f11f25aa1dd807934d0c25c9f2ea84b6ef76e5a7da28ee764.jpg', 'a4e39d55a243b747da4b9e6b8245a3e361303425fb314e32588d3bdd0e608d14.jpg', 'a5d409c237958025582e7c832b70fb260cac449613dfbeab7d015734ac31ba51.jpg', 'db0d1c0b45ed5498888483b981acaad23c301b43de34d3e7b0e4f744f91ff038.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22423\0e2df592-6a61-472a-9635-978b97459e5f_content_list.json
#         发现图片: a4e39d55a243b747da4b9e6b8245a3e361303425fb314e32588d3bdd0e608d14.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22423\images\a4e39d55a243b747da4b9e6b8245a3e361303425fb314e32588d3bdd0e608d14.jpg
#         原始图片说明: Fig. 1. CT-scan reconstruction of the thoracic aorta, showing the good caliber of the left subclavian artery. The ascending aorta is extremely calcified.
#         清理后图片说明: CT-scan reconstruction of the thoracic aorta, showing the good caliber of the left subclavian artery. The ascending aorta is extremely calcified.
#         发现图片: 145f64c2b799800f11f25aa1dd807934d0c25c9f2ea84b6ef76e5a7da28ee764.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22423\images\145f64c2b799800f11f25aa1dd807934d0c25c9f2ea84b6ef76e5a7da28ee764.jpg
#         原始图片说明: Fig. 2. Surgical exposure of the left axillary artery during the procedure. [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.]
#         清理后图片说明: Surgical exposure of the left axillary artery during the procedure. [Color figure can be viewed in the online issue, which is available at www.interscience.wiley.com.]
#         发现图片: a5d409c237958025582e7c832b70fb260cac449613dfbeab7d015734ac31ba51.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22423\images\a5d409c237958025582e7c832b70fb260cac449613dfbeab7d015734ac31ba51.jpg
#         原始图片说明: Fig. 3. A: Final result of the CoreValve implantation. B: Postoperative angiography shows a trivial anterior paravalvular leak.
#         清理后图片说明: A: Final result of the CoreValve implantation. B: Postoperative angiography shows a trivial anterior paravalvular leak.
#         发现图片: db0d1c0b45ed5498888483b981acaad23c301b43de34d3e7b0e4f744f91ff038.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22423\images\db0d1c0b45ed5498888483b981acaad23c301b43de34d3e7b0e4f744f91ff038.jpg
#         原始图片说明: Fig. 4. The final angiography shows the patency of the LIMA graft. No dissection of the left subclavian artery is present..
#         清理后图片说明: The final angiography shows the patency of the LIMA graft. No dissection of the left subclavian artery is present..
#
# >>> 处理 PDF 文件: 10.1002_ccd.22532.pdf
#     生成 DOI: 10.1002/ccd.22532
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22532.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22532\images 中找到 2 张图片： ['15cae2ef206f918b00601f0df46aa6297c66cab47430edf229dc51feb583b279.jpg', 'ea71efb1fc788c412d99829db1ef6e2c8fc29ee6fd2af453fd6fb6bf115c3a66.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22532\7a770a51-7534-4228-a006-93d5ef9c911a_content_list.json
#         发现图片: 15cae2ef206f918b00601f0df46aa6297c66cab47430edf229dc51feb583b279.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22532\images\15cae2ef206f918b00601f0df46aa6297c66cab47430edf229dc51feb583b279.jpg
#         原始图片说明: Fig. 1. A and B: Successful Transapical implantation of a 23 mm Edwards-Sapien Aortic Bioprosthesis. C: Residual staining of dye post TAVI shown by the white arrow which may be suggestive of aortic dissection.
#         清理后图片说明: A and B: Successful Transapical implantation of a 23 mm Edwards-Sapien Aortic Bioprosthesis. C: Residual staining of dye post TAVI shown by the white arrow which may be suggestive of aortic dissection.
#         发现图片: ea71efb1fc788c412d99829db1ef6e2c8fc29ee6fd2af453fd6fb6bf115c3a66.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22532\images\ea71efb1fc788c412d99829db1ef6e2c8fc29ee6fd2af453fd6fb6bf115c3a66.jpg
#         原始图片说明: Fig. 2. A: 2.4 cm intimal tear above the noncoronary cusp (black arrow) B: 1.2cm tear above the aortic valve which extends through the aortic adventita demonstrated by a stiIette through the orifice. [Color figure can be viewed in the online issue, which is available at www.interscience.wiley. com.]
#         清理后图片说明: A: 2.4 cm intimal tear above the noncoronary cusp (black arrow) B: 1.2cm tear above the aortic valve which extends through the aortic adventita demonstrated by a stiIette through the orifice. [Color figure can be viewed in the online issue, which is available at www.interscience.wiley. com.]
#
# >>> 处理 PDF 文件: 10.1002_ccd.22609.pdf
#     生成 DOI: 10.1002/ccd.22609
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22609.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22609\images 中找到 3 张图片： ['33eaabc00ab719d73384e3e04b437c5888ec9e1450c43d930a8ebefdaddc712b.jpg', 'c8a6197c87169b83e7c6e73970de088a94714e44b8adc098c2bd4ed0974fabe1.jpg', 'ffc300f21e13e8bbcec8b55cda560f8e496471bda06e89669632e3d67ba74b65.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22609\e253d9d0-a5bd-4734-bf83-d7a11757545b_content_list.json
#         发现图片: c8a6197c87169b83e7c6e73970de088a94714e44b8adc098c2bd4ed0974fabe1.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22609\images\c8a6197c87169b83e7c6e73970de088a94714e44b8adc098c2bd4ed0974fabe1.jpg
#         原始图片说明: Fig. 1. Transthoracic echocardiogram before TAvI. Panel A:. Apical four-chamber view at end-diastole. The septum has a sigmoid contour. Panel B: Apical four-chamber view at end-systole. There is near cavitary obliteration at the mid-ventricular. level. Panel C: Continuous wave Doppler interrogation across. the mid-ventricular obstruction. There is E to A reversal which  is consistent with grade 1 diastolic dysfunction. There is a late peaking gradient across the mid-ventricular obstruction with a. peak velocity of 1.7 m sec-1 which gives a gradient of 12 mm. Hg. Panel D: Continuous wave Doppler interrogation across the. aortic valve. The peak velocity was 5.5 m sec-1. Peak gradient. was 121 mm Hg and mean gradient was 83 mm Hg.
#         清理后图片说明: Transthoracic echocardiogram before TAvI. Panel A:. Apical four-chamber view at end-diastole. The septum has a sigmoid contour. Panel B: Apical four-chamber view at end-systole. There is near cavitary obliteration at the mid-ventricular. level. Panel C: Continuous wave Doppler interrogation across. the mid-ventricular obstruction. There is E to A reversal which  is consistent with grade 1 diastolic dysfunction. There is a late peaking gradient across the mid-ventricular obstruction with a. peak velocity of 1.7 m sec-1 which gives a gradient of 12 mm. Hg. Panel D: Continuous wave Doppler interrogation across the. aortic valve. The peak velocity was 5.5 m sec-1. Peak gradient. was 121 mm Hg and mean gradient was 83 mm Hg.
#         发现图片: 33eaabc00ab719d73384e3e04b437c5888ec9e1450c43d930a8ebefdaddc712b.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22609\images\33eaabc00ab719d73384e3e04b437c5888ec9e1450c43d930a8ebefdaddc712b.jpg
#         原始图片说明: Fig. 2. Left ventriculography in the RAO projection. Panel A: Cineangiographic frame of the. Ieft ventricle in end-diastole. The stented bioprosthetic aortic valve is well-seated. Panel B: Cineangiographic frame of the left ventricle in end-systole. There is cavitary obliteration at. the mid-ventricular level with sparing of the left ventricular outflow tract..
#         清理后图片说明: Left ventriculography in the RAO projection. Panel A: Cineangiographic frame of the. Ieft ventricle in end-diastole. The stented bioprosthetic aortic valve is well-seated. Panel B: Cineangiographic frame of the left ventricle in end-systole. There is cavitary obliteration at. the mid-ventricular level with sparing of the left ventricular outflow tract..
#         发现图片: ffc300f21e13e8bbcec8b55cda560f8e496471bda06e89669632e3d67ba74b65.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22609\images\ffc300f21e13e8bbcec8b55cda560f8e496471bda06e89669632e3d67ba74b65.jpg
#         原始图片说明: Fig. 3. Transesophageal echocardiogram after TAVl. Panel A: Transgastric long axis view of the Ieft ventricle in end-diastole. There is left ventricular hypertrophy. Panel B: Transgastric long axis view of the left ventricle in end-systole. There is cavitary obliteration in end-systole. Panel C: Continuous wave Doppler interrogation of the mid-cavitary obstruction. There is a late peaking gradient with a peak velocity of 2.5 m sec-1 which gives a gradient of 24 mm Hg.
#         清理后图片说明: Transesophageal echocardiogram after TAVl. Panel A: Transgastric long axis view of the Ieft ventricle in end-diastole. There is left ventricular hypertrophy. Panel B: Transgastric long axis view of the left ventricle in end-systole. There is cavitary obliteration in end-systole. Panel C: Continuous wave Doppler interrogation of the mid-cavitary obstruction. There is a late peaking gradient with a peak velocity of 2.5 m sec-1 which gives a gradient of 24 mm Hg.
#
# >>> 处理 PDF 文件: 10.1002_ccd.22684.pdf
#     生成 DOI: 10.1002/ccd.22684
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22684.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22684\images 中找到 3 张图片： ['04b1e0ba07983ba654ea51e49cfdeafd5e0336c4519596207f349e7444f65042.jpg', 'cb50352130f7055ce1108263b46d10c7721d66b00b4a82a8a6d1abd8f9cd7b5f.jpg', 'f0873e661b0788af237a0b9e7ac9a0cd6d697a11edf2fa6c61d6ad04a3b6b888.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22684\d037ef69-8837-4733-a3ab-f46960c07630_content_list.json
#         发现图片: cb50352130f7055ce1108263b46d10c7721d66b00b4a82a8a6d1abd8f9cd7b5f.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22684\images\cb50352130f7055ce1108263b46d10c7721d66b00b4a82a8a6d1abd8f9cd7b5f.jpg
#         原始图片说明: Fig. 1. Failure of prosthetic valve to cross.
#         清理后图片说明: Failure of prosthetic valve to cross.
#         发现图片: f0873e661b0788af237a0b9e7ac9a0cd6d697a11edf2fa6c61d6ad04a3b6b888.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22684\images\f0873e661b0788af237a0b9e7ac9a0cd6d697a11edf2fa6c61d6ad04a3b6b888.jpg
#         原始图片说明: Fig. 2. Buddy balloon inflated.
#         清理后图片说明: Buddy balloon inflated.
#         发现图片: 04b1e0ba07983ba654ea51e49cfdeafd5e0336c4519596207f349e7444f65042.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22684\images\04b1e0ba07983ba654ea51e49cfdeafd5e0336c4519596207f349e7444f65042.jpg
#         原始图片说明: Fig. 3. Prosthetic valve crossing.
#         清理后图片说明: Prosthetic valve crossing.
#
# >>> 处理 PDF 文件: 10.1002_ccd.22808.pdf
#     生成 DOI: 10.1002/ccd.22808
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22808.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22808\images 中找到 7 张图片： ['3387888c526fb75f6bcff29eb3dfeafbb23e46927d08d2e570ec5d8be6db2980.jpg', '4d27d06d273d313ffb1598849cc12a15f24ecc07975691ccf5812b19b4eba224.jpg', '7114ec17c058ea46c6f6d16889ac827d37ef4a7ce67ade05ecd71e845bcb786e.jpg', '7e0e390fe89a5c2cf4ffd2f726feeef6022f7cfd0c2e4acec4695deaaaf19d76.jpg', 'a2bc909f357f4e40e353f7b39198bad6c4cf6aaad9d70c2e62a26d77f30647e6.jpg', 'ac37c7ab77c86a57b0bdd1527b8da812fc4b3696e91db61662fb2b689bd9a747.jpg', 'dda1225da14de78630c0a113bf0613b7aaec7d345a0bfc348185b22babb099c5.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22808\dc1dc271-4c7d-4a1d-b170-6be9e2e4fda1_content_list.json
#         发现图片: ac37c7ab77c86a57b0bdd1527b8da812fc4b3696e91db61662fb2b689bd9a747.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22808\images\ac37c7ab77c86a57b0bdd1527b8da812fc4b3696e91db61662fb2b689bd9a747.jpg
#         原始图片说明: Fig. 1. Simultaneous pressure tracings of the aorta and the left ventricle revealing the severity of the aortic stenosis.
#         清理后图片说明: Simultaneous pressure tracings of the aorta and the left ventricle revealing the severity of the aortic stenosis.
#         发现图片: 3387888c526fb75f6bcff29eb3dfeafbb23e46927d08d2e570ec5d8be6db2980.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22808\images\3387888c526fb75f6bcff29eb3dfeafbb23e46927d08d2e570ec5d8be6db2980.jpg
#         原始图片说明: Fig. 2. Aortography during balloon expansion without compromise of the coronary ostia..
#         清理后图片说明: Aortography during balloon expansion without compromise of the coronary ostia..
#         发现图片: dda1225da14de78630c0a113bf0613b7aaec7d345a0bfc348185b22babb099c5.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22808\images\dda1225da14de78630c0a113bf0613b7aaec7d345a0bfc348185b22babb099c5.jpg
#         原始图片说明: Fig. 3. Electrocardiogram immediately post the Edwards SAPiEN prosthesis implantation revealing the ST segment elevations in the leads of the inferior wall. Systolic blood pressure is collapsed. (black arrow)
#         清理后图片说明: Electrocardiogram immediately post the Edwards SAPiEN prosthesis implantation revealing the ST segment elevations in the leads of the inferior wall. Systolic blood pressure is collapsed. (black arrow)
#         发现图片: 7114ec17c058ea46c6f6d16889ac827d37ef4a7ce67ade05ecd71e845bcb786e.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22808\images\7114ec17c058ea46c6f6d16889ac827d37ef4a7ce67ade05ecd71e845bcb786e.jpg
#         原始图片说明: Fig. 4. Aortography reveales ostial occlusion of the right coronary artery.
#         清理后图片说明: Aortography reveales ostial occlusion of the right coronary artery.
#         发现图片: 4d27d06d273d313ffb1598849cc12a15f24ecc07975691ccf5812b19b4eba224.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22808\images\4d27d06d273d313ffb1598849cc12a15f24ecc07975691ccf5812b19b4eba224.jpg
#         原始图片说明: Fig. 5. Direct stenting of the right coronary artery.
#         清理后图片说明: Direct stenting of the right coronary artery.
#         发现图片: 7e0e390fe89a5c2cf4ffd2f726feeef6022f7cfd0c2e4acec4695deaaaf19d76.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22808\images\7e0e390fe89a5c2cf4ffd2f726feeef6022f7cfd0c2e4acec4695deaaaf19d76.jpg
#         原始图片说明: Fig. 6. TIMI III flow with good myocardial blush after direct stenting of the right coronary artery..
#         清理后图片说明: TIMI III flow with good myocardial blush after direct stenting of the right coronary artery..
#         发现图片: a2bc909f357f4e40e353f7b39198bad6c4cf6aaad9d70c2e62a26d77f30647e6.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22808\images\a2bc909f357f4e40e353f7b39198bad6c4cf6aaad9d70c2e62a26d77f30647e6.jpg
#         原始图片说明: Fig. 7. Final aortography.
#         清理后图片说明: Final aortography.
#
# >>> 处理 PDF 文件: 10.1002_ccd.22861.pdf
#     生成 DOI: 10.1002/ccd.22861
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22861.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\images 中找到 8 张图片： ['2737868eb52435badda2a87affcd5fc796c52ac93af004b9205f39f3fe7227a2.jpg', '495ab099cdfaa82fcf7adfef42d0a7b38b63bf6cf06b97861f5f79585ddd4994.jpg', '4d5c0361537d2426a4c08422159a5266097f1c6bd511fcac4893266b874acf6f.jpg', '5d54a316e6b70319d2f7a6a77ab2c59483acd09ce8afafd1080afb8c672722a1.jpg', '81c835391d9ae4ce7e3d582e18deeb89254e954a257ecf7bf1fada17068fb26e.jpg', '95316a33e93f9d66150d4ba3c391ea135991a54c265dc1d684589ed701bbb47f.jpg', 'c5b33d9ac09f2705e3eeeb1e4b6f09b122f7a3d7dff082e83ecd51bef0568918.jpg', 'fd46f927273618b24690a3ea2b71c17a37db240c4b54ac02161f269d643ba038.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\09a918d5-c389-44aa-b2e3-1a867a67b157_content_list.json
#         发现图片: 81c835391d9ae4ce7e3d582e18deeb89254e954a257ecf7bf1fada17068fb26e.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\images\81c835391d9ae4ce7e3d582e18deeb89254e954a257ecf7bf1fada17068fb26e.jpg
#         原始图片说明: Fig. 1. A. Baseline aortic root angiography. Native left coronary artery (black arrow) and radiopaque silicone sewing ring, attached to the outer perimeter of the inflow side of the Mitroflow valve (white arrow). The relationship of the left coronary ostium to the Mitroflow bioprosthesis is demonstrated. B. Selective coronary angiography of the left coronary artery showing no significant left main disease and moderate stenosis in the mid left anterior descending artery.
#         清理后图片说明: A. Baseline aortic root angiography. Native left coronary artery (black arrow) and radiopaque silicone sewing ring, attached to the outer perimeter of the inflow side of the Mitroflow valve (white arrow). The relationship of the left coronary ostium to the Mitroflow bioprosthesis is demonstrated. B. Selective coronary angiography of the left coronary artery showing no significant left main disease and moderate stenosis in the mid left anterior descending artery.
#         发现图片: 495ab099cdfaa82fcf7adfef42d0a7b38b63bf6cf06b97861f5f79585ddd4994.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\images\495ab099cdfaa82fcf7adfef42d0a7b38b63bf6cf06b97861f5f79585ddd4994.jpg
#         原始图片说明: Fig. 2. A. Aortic valvuloplasty using a Z-Med 20 mm x 4 mm balloon. A slight waist is seen. in the midportion of the balloon. B. Deployment of a 23-mm Edwards SAPIEN valve. Correct angiographic position was achieved, with the base of the SAPIEN valve below the sewing. ring of the Mitroflow bioprosthesis. A waist can be seen in the SAPIEN valve given the con-. straints of the external bioprosthesis..
#         清理后图片说明: A. Aortic valvuloplasty using a Z-Med 20 mm x 4 mm balloon. A slight waist is seen. in the midportion of the balloon. B. Deployment of a 23-mm Edwards SAPIEN valve. Correct angiographic position was achieved, with the base of the SAPIEN valve below the sewing. ring of the Mitroflow bioprosthesis. A waist can be seen in the SAPIEN valve given the con-. straints of the external bioprosthesis..
#         发现图片: 2737868eb52435badda2a87affcd5fc796c52ac93af004b9205f39f3fe7227a2.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\images\2737868eb52435badda2a87affcd5fc796c52ac93af004b9205f39f3fe7227a2.jpg
#         原始图片说明: Fig. 3. Angiography using a Judkins Left 4-cm catheter. The Ieft coronary could not be opacified. A leaflet from the Mitroflow bioprosthesis can be seen to be overriding the SAPIEN valve and occluding the left main coronary ostium (inset, black arrow).
#         清理后图片说明: Angiography using a Judkins Left 4-cm catheter. The Ieft coronary could not be opacified. A leaflet from the Mitroflow bioprosthesis can be seen to be overriding the SAPIEN valve and occluding the left main coronary ostium (inset, black arrow).
#         发现图片: 5d54a316e6b70319d2f7a6a77ab2c59483acd09ce8afafd1080afb8c672722a1.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\images\5d54a316e6b70319d2f7a6a77ab2c59483acd09ce8afafd1080afb8c672722a1.jpg
#         原始图片说明: Fig. 4. Attempted coronary angioplasty. A Choice PT-2 (Boston scientific, Natick, MA) introduced via a guiding catheter in the ascending aorta is seen to loop over (black arrow), unable to be passed into the left main coronary artery.
#         清理后图片说明: Attempted coronary angioplasty. A Choice PT-2 (Boston scientific, Natick, MA) introduced via a guiding catheter in the ascending aorta is seen to loop over (black arrow), unable to be passed into the left main coronary artery.
#         发现图片: fd46f927273618b24690a3ea2b71c17a37db240c4b54ac02161f269d643ba038.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\images\fd46f927273618b24690a3ea2b71c17a37db240c4b54ac02161f269d643ba038.jpg
#         原始图片说明: Fig. 5. Selective coronary angiography showing the relationship of the left coronary ostium to the Mitroflow bioprosthesis (case 2). No significant angiographic coronary stenoses are seen.
#         清理后图片说明: Selective coronary angiography showing the relationship of the left coronary ostium to the Mitroflow bioprosthesis (case 2). No significant angiographic coronary stenoses are seen.
#         发现图片: 95316a33e93f9d66150d4ba3c391ea135991a54c265dc1d684589ed701bbb47f.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\images\95316a33e93f9d66150d4ba3c391ea135991a54c265dc1d684589ed701bbb47f.jpg
#         原始图片说明: Fig. 6. Final position of the Corevalve bioprostesis inside the Mitroflow.
#         清理后图片说明: Final position of the Corevalve bioprostesis inside the Mitroflow.
#         发现图片: 4d5c0361537d2426a4c08422159a5266097f1c6bd511fcac4893266b874acf6f.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\images\4d5c0361537d2426a4c08422159a5266097f1c6bd511fcac4893266b874acf6f.jpg
#         原始图片说明: Fig. 7.  A. Aortography showing a valve leaflet overriding the left main ostium (inset, black arrow).. Flow could be seen in the left coronary but this was very slow and sluggish. B. Attempted coronary. angioplasty. A choice PT-2 guidewire introduced via a guiding catheter in the ascending aorta can be seen to extend above the leaflet but could not be passed into the left main coronary artery..
#         清理后图片说明: A. Aortography showing a valve leaflet overriding the left main ostium (inset, black arrow).. Flow could be seen in the left coronary but this was very slow and sluggish. B. Attempted coronary. angioplasty. A choice PT-2 guidewire introduced via a guiding catheter in the ascending aorta can be seen to extend above the leaflet but could not be passed into the left main coronary artery..
#         发现图片: c5b33d9ac09f2705e3eeeb1e4b6f09b122f7a3d7dff082e83ecd51bef0568918.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22861\images\c5b33d9ac09f2705e3eeeb1e4b6f09b122f7a3d7dff082e83ecd51bef0568918.jpg
#         原始图片说明: Fig. 8. Four different aortic bioprostheses, demonstrating the location of the valve leaflets in. relation to the stent frame: (A) Carpentier Edwards PERIMOuNT, (B) St. Jude Medical EPIC, (C) Medtronic MOsAIC, and (D) Sorin Medical Mitroflow valve. In A-C, the leaflets can be. seen to be on the inside of valve stent frame. In D, the pericardial leaflets are seen on the. outside of the valve stent frame (stent frame cannot be seen). [Color figure can be viewed in the online issue, which is available at wileyonlinelibrary.com.].
#         清理后图片说明: Four different aortic bioprostheses, demonstrating the location of the valve leaflets in. relation to the stent frame: (A) Carpentier Edwards PERIMOuNT, (B) St. Jude Medical EPIC, (C) Medtronic MOsAIC, and (D) Sorin Medical Mitroflow valve. In A-C, the leaflets can be. seen to be on the inside of valve stent frame. In D, the pericardial leaflets are seen on the. outside of the valve stent frame (stent frame cannot be seen). [Color figure can be viewed in the online issue, which is available at wileyonlinelibrary.com.].
#
# >>> 处理 PDF 文件: 10.1002_ccd.22900.pdf
#     生成 DOI: 10.1002/ccd.22900
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.1002_ccd.22900.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.1002_ccd.22900\images 中找到 7 张图片： ['7e4299fed17ea05967ef945900d6920592de332251da506ee04d123bee31cf14.jpg', '9d7ddd1d28869a2f4fc381998692a495c51b2c62043e2b2f209eb185ea75889b.jpg', 'a039e6f370ee59512a4727c2d86e5a24a8d4c2951a172288d7a705a412ce0d22.jpg', 'bfc4d890d64cd04a64b249fadce1ce12464ab1bd746a31a8f847ff07fd1cd5cd.jpg', 'd3509ab1c1aa64f3c1de17b84a5a06107b686089bcc1d89f6db31118702147c5.jpg', 'e5de4c4a2a051f558e3ab1b90a48b299340a3c07c5d4ad98806a9a4700e3da3b.jpg', 'f0080eca7236e7193f5c1bd7f1f470f6a924910fed3a603a5ffd20aa38bbc4b6.jpg']
# ...
#         发现图片: b8d3994559d1e914c81ab32d5fe6e8dc4efc6f46b2412f0c5874606f1440610a.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.69453\images\b8d3994559d1e914c81ab32d5fe6e8dc4efc6f46b2412f0c5874606f1440610a.jpg
#         原始图片说明: FIGURE 1: The remarkable tracer uptake around the vascular graft seen in 2021 (A1) decreases in 2022 (B1) up to normalization in 2023 (C1). Likewise the subcutaneous focus outside the sternum. Intense tracer uptake on the valve plan in 2021 (A2). Uptake reduction in 2022 (B2) and complete response to treatment in 2023 (C2). Bilateral pleural effusion in 2023 due to worsening of cardiac function, also highlited by the heart dilatation.
#         清理后图片说明: : The remarkable tracer uptake around the vascular graft seen in 2021 (A1) decreases in 2022 (B1) up to normalization in 2023 (C1). Likewise the subcutaneous focus outside the sternum. Intense tracer uptake on the valve plan in 2021 (A2). Uptake reduction in 2022 (B2) and complete response to treatment in 2023 (C2). Bilateral pleural effusion in 2023 due to worsening of cardiac function, also highlited by the heart dilatation.
#         发现图片: d8ce182f887ffd654871ad09fc2e4de8b575be54e074a9050c3c195c57870c27.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.69453\images\d8ce182f887ffd654871ad09fc2e4de8b575be54e074a9050c3c195c57870c27.jpg
#         原始图片说明: N/A
#         清理后图片说明: N/A
#
# >>> 处理 PDF 文件: 10.7759_cureus.72143.pdf
#     生成 DOI: 10.7759/cureus.72143
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.7759_cureus.72143.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.72143\images 中找到 2 张图片： ['3f4a285ed4c4a4f8bab194120f76316755176d390b809d831e79e6bdefec857c.jpg', 'f4489fcab24c2be179804d7d9fe2ea3c091d6cdffa7baf67f4504df6a7846da8.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus
jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.9073.Cureus\images\ffdce590cfef5cba31f98f8132e9f76be118b97ddd18a1e103fa322cd9b366b1.jpg
#         原始图片说明: FIGURE 3: Three-dimensional CT imaging of the origin and course of the right coronary artery (black arrow) and the left coronary artery (yellow arrow)
#         清理后图片说明: : Three-dimensional CT imaging of the origin and course of the right coronary artery (black arrow) and the left coronary artery (yellow arrow)
#         发现图片: 25a44b71d44e96d62efa1d455c9c39b4afea652811e3ea548b8a7ab1f1c34340.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.9073.Cureus\images\25a44b71d44e96d62efa1d455c9c39b4afea652811e3ea548b8a7ab1f1c34340.jpg
#         原始图片说明: FIGURE 4: Two-dimensional transthoracal echocardiography showing left ventricular ejection fraction of 47%
#         清理后图片说明: : Two-dimensional transthoracal echocardiography showing left ventricular ejection fraction of 47%
#
# >>> 处理 PDF 文件: 10.7759_cureus.9879.Cureus.pdf
#     生成 DOI: 10.7759/cureus.9879.Cureus
#     PDF 完整路径: E:/SAIRI/TAVI/Code/pdf_downloads\10.7759_cureus.9879.Cureus.pdf
#     在 E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.9879.Cureus\images 中找到 4 张图片： ['5360daed2d40a73f86f49e48c07629d242a7102d4d4a0cc550dc2a36e6b4c65b.jpg', 'c476401ebc3a3e069223ae64c52355cbf57d2b090fd4cadee93e0908c87775f4.jpg', 'c52907a6ec7e535f04e8a19f3c9a1219b58b1ea48e14a42d208ce27e91b60e1c.jpg', 'cb82e1062b54803b1aecebcea90940020d850f37b858498761082ad407933653.jpg']
#     读取 content_list.json 文件：E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.9879.Cureus\9a6a48a9-bdb8-4c13-992c-aae1294ca6a9_content_list.json
#         发现图片: cb82e1062b54803b1aecebcea90940020d850f37b858498761082ad407933653.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.9879.Cureus\images\cb82e1062b54803b1aecebcea90940020d850f37b858498761082ad407933653.jpg
#         原始图片说明: FIGURE 1: A rapidly growing pelvic mass, initially (A) and at
#         清理后图片说明: : A rapidly growing pelvic mass, initially (A) and at
#         发现图片: 5360daed2d40a73f86f49e48c07629d242a7102d4d4a0cc550dc2a36e6b4c65b.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.9879.Cureus\images\5360daed2d40a73f86f49e48c07629d242a7102d4d4a0cc550dc2a36e6b4c65b.jpg
#         原始图片说明: FIGURE 2: Ischemia of the abdominal mesentery.
#         清理后图片说明: : Ischemia of the abdominal mesentery.
#         发现图片: c52907a6ec7e535f04e8a19f3c9a1219b58b1ea48e14a42d208ce27e91b60e1c.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.9879.Cureus\images\c52907a6ec7e535f04e8a19f3c9a1219b58b1ea48e14a42d208ce27e91b60e1c.jpg
#         原始图片说明: N/A
#         清理后图片说明: N/A
#         发现图片: c476401ebc3a3e069223ae64c52355cbf57d2b090fd4cadee93e0908c87775f4.jpg
#         图片路径: E:/SAIRI/TAVI/Code/extract_downloads\10.7759_cureus.9879.Cureus\images\c476401ebc3a3e069223ae64c52355cbf57d2b090fd4cadee93e0908c87775f4.jpg
#         原始图片说明: FIGURE 4: Hematoxylin and eosin (H&E) staining at x200 showing round blue cells with hyperchromatic nuclear chromatin and mitotic figures arranged in a sheet.
#         清理后图片说明: : Hematoxylin and eosin (H&E) staining at x200 showing round blue cells with hyperchromatic nuclear chromatin and mitotic figures arranged in a sheet.
# 所有 layout 数据已写入数据库
# Merged JSON data written to E:/SAIRI/TAVI/Code/data/db_output.json
# Done
